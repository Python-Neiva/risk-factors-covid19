# %% [markdown]
# <a href="https://colab.research.google.com/github/Python-Neiva/risk-factors-covid19/blob/main/CSV_from_datos_gov_co.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import datetime

# %%
import requests

csv_url = "https://www.datos.gov.co/api/views/gt2j-8ykr/rows.csv?departamento_nom=HUILA&accessType=DOWNLOAD&api_foundry=true"
#csv_url = "./content/sample_data/sample_downloaded.csv"
root_path = "/content/drive/MyDrive/Salisbury/data/covid_downloaded.csv"
def downloadDataCsv(csv_url,root_path):
  req = requests.get(csv_url)
  url_content = req.content
  try:
      csv_file = open(root_path, 'wb')

      csv_file.write(url_content)

      csv_file.close()
      print("I finished")

  except:
      print("something was wrong")

downloadDataCsv(csv_url,root_path)
# Out:
# I finished

# %%
#sample_data
path= '/content/sample_data/sample_downloaded.csv'
df = pd.read_csv (r''+path)
df.head(10)
#Google drive
path = '/content/drive/MyDrive/Salisbury/data/covid_downloaded.csv'
df2 = pd.read_csv (r''+path)
df2.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (14,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    fecha reporte web  ID de caso  ... Pertenencia étnica  Nombre del grupo étnico
# 0   6/3/2020 0:00:00         1.0  ...                6.0                      NaN
# 1   9/3/2020 0:00:00         2.0  ...                5.0                      NaN
# 2   9/3/2020 0:00:00         3.0  ...                6.0                      NaN
# 3  11/3/2020 0:00:00         4.0  ...                6.0                      NaN
# ...

# %%
df.head(10)
# Out:
#    fecha reporte web  ID de caso  ... Pertenencia étnica  Nombre del grupo étnico
# 0   6/3/2020 0:00:00           1  ...                6.0                      NaN
# 1   9/3/2020 0:00:00           2  ...                5.0                      NaN
# 2   9/3/2020 0:00:00           3  ...                6.0                      NaN
# 3  11/3/2020 0:00:00           4  ...                6.0                      NaN
# 4  11/3/2020 0:00:00           5  ...                6.0                      NaN
# 5  11/3/2020 0:00:00           6  ...                6.0                      NaN
# 6  11/3/2020 0:00:00           7  ...                6.0                      NaN
# 7  11/3/2020 0:00:00           8  ...                6.0                      NaN
# 8  11/3/2020 0:00:00           9  ...                6.0                      NaN
# 9  12/3/2020 0:00:00          10  ...                6.0                      NaN
#
# [10 rows x 23 columns]

# %%
import os
os.chdir("/content/drive/MyDrive/Salisbury/data")
# !ls
# Out:
# covid_downloaded.csv

# %%
df.columns = [
  'web_date_report',
  'case_id',
  'notification_date',
  'davipola_departament_code',
  'department_name',
  'davipola_municipality_code',
  'municipality_name',
  'age',
  'age_measurement_unit',
  'sex',
  'contagion_type',
  'case_location',
  'state',
  'iso_country_code',
  'country_name',
  'recuperated', #spell correctly
  'beginning_symptoms_date',
  'date_of_diagnosis',
  'date_of_recovery',
  'recovery_type',
  'ethnicity',
  'date_of_death',
  'ethnic_group_name',
]

# %%
df.head()
# Out:
#      web_date_report  case_id  ... ethnicity  ethnic_group_name
# 0   6/3/2020 0:00:00        1  ...       6.0                NaN
# 1   9/3/2020 0:00:00        2  ...       5.0                NaN
# 2   9/3/2020 0:00:00        3  ...       6.0                NaN
# 3  11/3/2020 0:00:00        4  ...       6.0                NaN
# 4  11/3/2020 0:00:00        5  ...       6.0                NaN
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3945166 entries, 0 to 3945165
# Data columns (total 23 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   web_date_report             object
#  1   case_id                     int64
#  2   notification_date           object
#  3   davipola_departament_code   int64
#  4   departament_name            object
#  5   davipola_municipality_code  int64
#  6   municipality_name           object
#  7   age                         int64
#  8   age_measurement_unit        int64
#  9   sex                         object
#  10  contagion_type              object
#  11  case_location               object
#  12  state                       object
#  13  iso_country_code            float64
#  14  country_name                object
#  15  recuperated                 object
#  16  beginning_symptoms_date     object
#  17  date_of_death               object
#  18  date_of_diagnosis           object
# ...
